# %%
#install relevant packages
# !pip install statsbombpy
# !pip install mplsoccer
# !pip install highlight_text
# Out:
# Requirement already satisfied: statsbombpy in ./bitirme-venv/lib/python3.9/site-packages (1.14.0)
# Requirement already satisfied: requests in ./bitirme-venv/lib/python3.9/site-packages (from statsbombpy) (2.32.3)
# Requirement already satisfied: pandas in ./bitirme-venv/lib/python3.9/site-packages (from statsbombpy) (2.2.3)
# Requirement already satisfied: inflect in ./bitirme-venv/lib/python3.9/site-packages (from statsbombpy) (7.4.0)
# Requirement already satisfied: joblib in ./bitirme-venv/lib/python3.9/site-packages (from statsbombpy) (1.4.2)
# Requirement already satisfied: requests-cache in ./bitirme-venv/lib/python3.9/site-packages (from statsbombpy) (1.2.1)
# Requirement already satisfied: typeguard>=4.0.1 in ./bitirme-venv/lib/python3.9/site-packages (from inflect->statsbombpy) (4.3.0)
# Requirement already satisfied: more-itertools>=8.5.0 in ./bitirme-venv/lib/python3.9/site-packages (from inflect->statsbombpy) (10.5.0)
# Requirement already satisfied: importlib-metadata>=3.6 in ./bitirme-venv/lib/python3.9/site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./bitirme-venv/lib/python3.9/site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in ./bitirme-venv/lib/python3.9/site-packages (from importlib-metadata>=3.6->typeguard>=4.0.1->inflect->statsbombpy) (3.20.2)
# Requirement already satisfied: tzdata>=2022.7 in ./bitirme-venv/lib/python3.9/site-packages (from pandas->statsbombpy) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./bitirme-venv/lib/python3.9/site-packages (from pandas->statsbombpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./bitirme-venv/lib/python3.9/site-packages (from pandas->statsbombpy) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in ./bitirme-venv/lib/python3.9/site-packages (from pandas->statsbombpy) (2.0.2)
# Requirement already satisfied: six>=1.5 in ./bitirme-venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./bitirme-venv/lib/python3.9/site-packages (from requests->statsbombpy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./bitirme-venv/lib/python3.9/site-packages (from requests->statsbombpy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./bitirme-venv/lib/python3.9/site-packages (from requests->statsbombpy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./bitirme-venv/lib/python3.9/site-packages (from requests->statsbombpy) (2024.8.30)
# Requirement already satisfied: url-normalize>=1.4 in ./bitirme-venv/lib/python3.9/site-packages (from requests-cache->statsbombpy) (1.4.3)
# Requirement already satisfied: platformdirs>=2.5 in ./bitirme-venv/lib/python3.9/site-packages (from requests-cache->statsbombpy) (4.3.6)
# Requirement already satisfied: cattrs>=22.2 in ./bitirme-venv/lib/python3.9/site-packages (from requests-cache->statsbombpy) (24.1.2)
# Requirement already satisfied: attrs>=21.2 in ./bitirme-venv/lib/python3.9/site-packages (from requests-cache->statsbombpy) (24.2.0)
# Requirement already satisfied: exceptiongroup>=1.1.1 in ./bitirme-venv/lib/python3.9/site-packages (from cattrs>=22.2->requests-cache->statsbombpy) (1.2.2)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/emirysaglam/GitHub/Bitirme/bitirme-venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: mplsoccer in ./bitirme-venv/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: seaborn in ./bitirme-venv/lib/python3.9/site-packages (from mplsoccer) (0.13.2)
# Requirement already satisfied: pillow in ./bitirme-venv/lib/python3.9/site-packages (from mplsoccer) (11.0.0)
# Requirement already satisfied: matplotlib>=3.6 in ./bitirme-venv/lib/python3.9/site-packages (from mplsoccer) (3.9.2)
# Requirement already satisfied: requests in ./bitirme-venv/lib/python3.9/site-packages (from mplsoccer) (2.32.3)
# Requirement already satisfied: scipy in ./bitirme-venv/lib/python3.9/site-packages (from mplsoccer) (1.13.1)
# Requirement already satisfied: pandas in ./bitirme-venv/lib/python3.9/site-packages (from mplsoccer) (2.2.3)
# Requirement already satisfied: numpy in ./bitirme-venv/lib/python3.9/site-packages (from mplsoccer) (2.0.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./bitirme-venv/lib/python3.9/site-packages (from matplotlib>=3.6->mplsoccer) (6.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./bitirme-venv/lib/python3.9/site-packages (from matplotlib>=3.6->mplsoccer) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in ./bitirme-venv/lib/python3.9/site-packages (from matplotlib>=3.6->mplsoccer) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./bitirme-venv/lib/python3.9/site-packages (from matplotlib>=3.6->mplsoccer) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./bitirme-venv/lib/python3.9/site-packages (from matplotlib>=3.6->mplsoccer) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./bitirme-venv/lib/python3.9/site-packages (from matplotlib>=3.6->mplsoccer) (24.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./bitirme-venv/lib/python3.9/site-packages (from matplotlib>=3.6->mplsoccer) (4.54.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./bitirme-venv/lib/python3.9/site-packages (from matplotlib>=3.6->mplsoccer) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in ./bitirme-venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6->mplsoccer) (3.20.2)
# Requirement already satisfied: six>=1.5 in ./bitirme-venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mplsoccer) (1.16.0)
# Requirement already satisfied: tzdata>=2022.7 in ./bitirme-venv/lib/python3.9/site-packages (from pandas->mplsoccer) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in ./bitirme-venv/lib/python3.9/site-packages (from pandas->mplsoccer) (2024.2)
# Requirement already satisfied: idna<4,>=2.5 in ./bitirme-venv/lib/python3.9/site-packages (from requests->mplsoccer) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./bitirme-venv/lib/python3.9/site-packages (from requests->mplsoccer) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./bitirme-venv/lib/python3.9/site-packages (from requests->mplsoccer) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./bitirme-venv/lib/python3.9/site-packages (from requests->mplsoccer) (2024.8.30)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/emirysaglam/GitHub/Bitirme/bitirme-venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: highlight_text in ./bitirme-venv/lib/python3.9/site-packages (0.2)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/emirysaglam/GitHub/Bitirme/bitirme-venv/bin/python -m pip install --upgrade pip' command.

# %%
#import packages
from statsbombpy import sb
import pandas as pd
from mplsoccer import VerticalPitch,Pitch
from highlight_text import ax_text, fig_text
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import seaborn as sns

# %% [markdown]
# # Load Competiton, Match, and Event Data from statsbombpy

# %%
#call statsbombpy API to get all free competitions
free_comps = sb.competitions()

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

#print a list of free competitions
free_comps
# Out:
#     competition_id  season_id               country_name  \
# 0                9        281                    Germany
# 1                9         27                    Germany
# 2             1267        107                     Africa
# 3               16          4                     Europe
# 4               16          1                     Europe
# 5               16          2                     Europe
# 6               16         27                     Europe
# 7               16         26                     Europe
# 8               16         25                     Europe
# 9               16         24                     Europe
# 10              16         23                     Europe
# 11              16         22                     Europe
# 12              16         21                     Europe
# 13              16         41                     Europe
# 14              16         39                     Europe
# 15              16         37                     Europe
# 16              16         44                     Europe
# 17              16         76                     Europe
# 18              16        277                     Europe
# 19              16         71                     Europe
# 20              16        276                     Europe
# 21             223        282              South America
# 22              87         84                      Spain
# 23              87        268                      Spain
# 24              87        279                      Spain
# 25              37         90                    England
# 26              37         42                    England
# 27              37          4                    England
# 28            1470        274              International
# 29              43        106              International
# 30              43          3              International
# 31              43         55              International
# 32              43         54              International
# 33              43         51              International
# 34              43        272              International
# 35              43        270              International
# 36              43        269              International
# 37            1238        108                      India
# 38              11         90                      Spain
# 39              11         42                      Spain
# 40              11          4                      Spain
# 41              11          1                      Spain
# 42              11          2                      Spain
# 43              11         27                      Spain
# 44              11         26                      Spain
# 45              11         25                      Spain
# 46              11         24                      Spain
# 47              11         23                      Spain
# 48              11         22                      Spain
# 49              11         21                      Spain
# 50              11         41                      Spain
# 51              11         40                      Spain
# 52              11         39                      Spain
# 53              11         38                      Spain
# 54              11         37                      Spain
# 55              11        278                      Spain
# 56              81         48                  Argentina
# 57              81        275                  Argentina
# 58               7        235                     France
# 59               7        108                     France
# 60               7         27                     France
# 61              44        107   United States of America
# 62             116         68  North and Central America
# 63              49          3   United States of America
# 64               2         27                    England
# 65               2         44                    England
# 66              12         27                      Italy
# 67              12         86                      Italy
# 68              55        282                     Europe
# 69              55         43                     Europe
# 70              35         75                     Europe
# 71              53        106                     Europe
# 72              72        107              International
# 73              72         30              International
#
#            competition_name competition_gender  competition_youth  \
# 0             1. Bundesliga               male              False
# 1             1. Bundesliga               male              False
# 2    African Cup of Nations               male              False
# 3          Champions League               male              False
# 4          Champions League               male              False
# 5          Champions League               male              False
# 6          Champions League               male              False
# 7          Champions League               male              False
# 8          Champions League               male              False
# 9          Champions League               male              False
# 10         Champions League               male              False
# 11         Champions League               male              False
# 12         Champions League               male              False
# 13         Champions League               male              False
# 14         Champions League               male              False
# 15         Champions League               male              False
# 16         Champions League               male              False
# 17         Champions League               male              False
# 18         Champions League               male              False
# 19         Champions League               male              False
# 20         Champions League               male              False
# 21             Copa America               male              False
# 22             Copa del Rey               male              False
# 23             Copa del Rey               male              False
# 24             Copa del Rey               male              False
# 25  FA Women's Super League             female              False
# 26  FA Women's Super League             female              False
# 27  FA Women's Super League             female              False
# 28       FIFA U20 World Cup               male              False
# 29           FIFA World Cup               male              False
# 30           FIFA World Cup               male              False
# 31           FIFA World Cup               male              False
# 32           FIFA World Cup               male              False
# 33           FIFA World Cup               male              False
# 34           FIFA World Cup               male              False
# 35           FIFA World Cup               male              False
# 36           FIFA World Cup               male              False
# 37      Indian Super league               male              False
# 38                  La Liga               male              False
# 39                  La Liga               male              False
# 40                  La Liga               male              False
# 41                  La Liga               male              False
# 42                  La Liga               male              False
# 43                  La Liga               male              False
# 44                  La Liga               male              False
# 45                  La Liga               male              False
# 46                  La Liga               male              False
# 47                  La Liga               male              False
# 48                  La Liga               male              False
# 49                  La Liga               male              False
# 50                  La Liga               male              False
# 51                  La Liga               male              False
# 52                  La Liga               male              False
# 53                  La Liga               male              False
# 54                  La Liga               male              False
# 55                  La Liga               male              False
# 56         Liga Profesional               male              False
# 57         Liga Profesional               male              False
# 58                  Ligue 1               male              False
# 59                  Ligue 1               male              False
# 60                  Ligue 1               male              False
# 61      Major League Soccer               male              False
# 62    North American League               male              False
# 63                     NWSL             female              False
# 64           Premier League               male              False
# 65           Premier League               male              False
# 66                  Serie A               male              False
# 67                  Serie A               male              False
# 68                UEFA Euro               male              False
# 69                UEFA Euro               male              False
# 70       UEFA Europa League               male              False
# 71        UEFA Women's Euro             female              False
# 72        Women's World Cup             female              False
# 73        Women's World Cup             female              False
#
#     competition_international season_name               match_updated  \
# 0                       False   2023/2024  2024-07-15T14:15:54.671676
# 1                       False   2015/2016  2024-05-19T11:11:14.192381
# 2                        True        2023  2024-06-13T07:51:02.452825
# 3                       False   2018/2019  2024-06-12T07:44:38.559714
# 4                       False   2017/2018  2024-02-13T02:35:28.134882
# 5                       False   2016/2017  2024-02-13T02:37:32.205154
# 6                       False   2015/2016  2024-06-12T07:45:38.786894
# 7                       False   2014/2015  2024-02-12T12:49:54.914228
# 8                       False   2013/2014  2024-02-12T12:48:48.479157
# 9                       False   2012/2013  2024-02-12T12:47:34.340413
# 10                      False   2011/2012  2024-02-13T02:36:35.698340
# 11                      False   2010/2011  2024-02-12T12:53:03.944320
# 12                      False   2009/2010  2024-02-12T12:49:25.017694
# 13                      False   2008/2009  2024-02-13T07:02:54.657056
# 14                      False   2006/2007  2024-02-12T13:48:23.967222
# 15                      False   2004/2005  2024-02-12T13:09:19.665986
# 16                      False   2003/2004  2024-02-12T13:51:22.366380
# 17                      False   1999/2000            2020-07-29T05:00
# 18                      False   1972/1973  2024-02-13T14:25:16.532771
# 19                      False   1971/1972  2024-02-12T14:25:01.735880
# 20                      False   1970/1971  2024-02-13T14:24:12.213582
# 21                       True        2024  2024-07-15T18:00:33.653673
# 22                      False   1983/1984  2024-02-13T01:54:12.946985
# 23                      False   1982/1983  2024-02-13T14:19:57.954551
# 24                      False   1977/1978  2024-02-13T14:26:19.978418
# 25                      False   2020/2021  2023-02-25T14:52:09.326729
# 26                      False   2019/2020  2024-02-12T15:05:34.211400
# 27                      False   2018/2019  2024-06-12T07:41:45.347457
# 28                      False        1979  2024-02-13T14:20:59.825440
# 29                       True        2022  2024-05-15T10:23:32.854925
# 30                       True        2018  2024-06-12T07:38:19.345758
# 31                       True        1990  2023-06-28T10:58:20.137929
# 32                       True        1986  2023-12-26T22:34:04.263530
# 33                       True        1974  2024-02-13T02:52:29.582599
# 34                       True        1970  2024-02-13T14:23:06.735299
# 35                       True        1962  2023-06-26T10:38:00.323984
# 36                       True        1958  2024-02-13T14:22:08.222297
# 37                      False   2021/2022  2024-02-12T17:41:31.729787
# 38                      False   2020/2021  2024-07-15T15:15:28.367546
# 39                      False   2019/2020  2024-07-12T16:27:54.561817
# 40                      False   2018/2019  2024-06-12T07:42:36.910303
# 41                      False   2017/2018  2024-06-12T07:32:43.196678
# 42                      False   2016/2017  2024-03-12T08:49:46.449084
# 43                      False   2015/2016  2024-05-16T14:06:52.149840
# 44                      False   2014/2015  2023-09-20T17:22:28.925900
# 45                      False   2013/2014  2022-07-23T12:18:49.547396
# 46                      False   2012/2013  2024-03-10T11:24:05.201066
# 47                      False   2011/2012  2022-12-01T14:10:17.791769
# 48                      False   2010/2011  2023-04-19T10:48:44.079830
# 49                      False   2009/2010  2023-11-29T10:55:10.039117
# 50                      False   2008/2009  2023-04-19T10:46:29.203565
# 51                      False   2007/2008  2023-04-19T10:42:35.284291
# 52                      False   2006/2007  2023-03-26T23:19:39.125951
# 53                      False   2005/2006  2022-07-03T12:34:31.749038
# 54                      False   2004/2005  2023-11-29T10:56:10.031508
# 55                      False   1973/1974  2023-07-06T12:50:48.807820
# 56                      False   1997/1998  2023-06-28T11:19:54.593488
# 57                      False        1981  2023-12-05T14:19:40.272816
# 58                      False   2022/2023  2024-06-11T00:50:53.277411
# 59                      False   2021/2022  2024-06-03T16:46:00.665854
# 60                      False   2015/2016  2024-01-07T06:23:44.277971
# 61                      False        2023  2024-07-14T18:53:28.735163
# 62                      False        1977  2024-02-12T14:20:24.769832
# 63                      False        2018  2023-07-24T13:01:22.094587
# 64                      False   2015/2016  2024-06-12T07:43:56.243851
# 65                      False   2003/2004  2024-03-08T14:49:13.195793
# 66                      False   2015/2016  2024-06-25T23:56:11.910924
# 67                      False   1986/1987  2023-06-18T01:55:53.343752
# 68                       True        2024  2024-07-15T15:48:50.315500
# 69                       True        2020  2024-04-16T12:44:40.558402
# 70                      False   1988/1989  2024-02-12T14:45:05.702250
# 71                       True        2022  2024-02-13T13:27:17.178263
# 72                       True        2023  2024-07-14T16:59:48.469596
# 73                       True        2019  2024-02-13T09:41:26.379767
#
#              match_updated_360         match_available_360  \
# 0   2024-07-15T14:17:00.877356  2024-07-15T14:17:00.877356
# 1                         None                        None
# 2                         None                        None
# 3      2021-06-13T16:17:31.694                        None
# 4      2021-06-13T16:17:31.694                        None
# 5      2021-06-13T16:17:31.694                        None
# 6      2021-06-13T16:17:31.694                        None
# 7      2021-06-13T16:17:31.694                        None
# 8      2021-06-13T16:17:31.694                        None
# 9      2021-06-13T16:17:31.694                        None
# 10     2021-06-13T16:17:31.694                        None
# 11     2021-06-13T16:17:31.694                        None
# 12     2021-06-13T16:17:31.694                        None
# 13     2021-06-13T16:17:31.694                        None
# 14     2021-06-13T16:17:31.694                        None
# 15     2021-06-13T16:17:31.694                        None
# 16     2021-06-13T16:17:31.694                        None
# 17     2021-06-13T16:17:31.694                        None
# 18                        None                        None
# 19     2021-06-13T16:17:31.694                        None
# 20                        None                        None
# 21                        None                        None
# 22     2021-06-13T16:17:31.694                        None
# 23                        None                        None
# 24                        None                        None
# 25     2021-06-13T16:17:31.694                        None
# 26     2021-06-13T16:17:31.694                        None
# 27     2021-06-13T16:17:31.694                        None
# 28                        None                        None
# 29  2024-06-11T11:30:50.462448  2024-06-11T11:30:50.462448
# 30     2021-06-13T16:17:31.694                        None
# 31     2021-06-12T16:17:31.694                        None
# 32     2021-06-13T16:17:31.694                        None
# 33     2021-06-13T16:17:31.694                        None
# 34                        None                        None
# 35                        None                        None
# 36                        None                        None
# 37                        None                        None
# 38  2024-07-15T15:17:45.455234  2024-07-15T15:17:45.455234
# 39     2021-06-13T16:17:31.694                        None
# 40  2021-07-09T14:53:22.103024                        None
# 41     2021-06-13T16:17:31.694                        None
# 42     2021-06-13T16:17:31.694                        None
# 43     2021-06-13T16:17:31.694                        None
# 44     2021-06-13T16:17:31.694                        None
# 45     2021-06-13T16:17:31.694                        None
# 46     2021-06-13T16:17:31.694                        None
# 47     2021-06-13T16:17:31.694                        None
# 48     2021-06-13T16:17:31.694                        None
# 49     2021-06-13T16:17:31.694                        None
# 50     2021-06-13T16:17:31.694                        None
# 51     2021-06-13T16:17:31.694                        None
# 52     2021-06-13T16:17:31.694                        None
# 53     2021-06-13T16:17:31.694                        None
# 54     2021-06-13T16:17:31.694                        None
# 55                        None                        None
# 56                        None                        None
# 57                        None                        None
# 58  2024-06-26T08:17:36.043856  2024-06-26T08:17:36.043856
# 59  2024-06-03T16:49:55.355195  2024-06-03T16:49:55.355195
# 60                        None                        None
# 61  2024-07-14T18:58:42.974543  2024-07-14T18:58:42.974543
# 62     2021-06-13T16:17:31.694                        None
# 63     2021-06-13T16:17:31.694                        None
# 64     2021-06-13T16:17:31.694                        None
# 65     2021-06-13T16:17:31.694                        None
# 66                        None                        None
# 67                        None                        None
# 68  2024-07-15T15:52:24.778809  2024-07-15T15:52:24.778809
# 69  2024-04-16T12:47:18.505110  2024-04-16T12:47:18.505110
# 70     2021-06-13T16:17:31.694                        None
# 71  2024-02-13T13:30:52.820588  2024-02-13T13:30:52.820588
# 72  2024-07-14T17:01:38.887279  2024-07-14T17:01:38.887279
# 73     2021-06-13T16:17:31.694                        None
#
#                match_available
# 0   2024-07-15T14:15:54.671676
# 1   2024-05-19T11:11:14.192381
# 2   2024-06-13T07:51:02.452825
# 3   2024-06-12T07:44:38.559714
# 4   2024-02-13T02:35:28.134882
# 5   2024-02-13T02:37:32.205154
# 6   2024-06-12T07:45:38.786894
# 7   2024-02-12T12:49:54.914228
# 8   2024-02-12T12:48:48.479157
# 9   2024-02-12T12:47:34.340413
# 10  2024-02-13T02:36:35.698340
# 11  2024-02-12T12:53:03.944320
# 12  2024-02-12T12:49:25.017694
# 13  2024-02-13T07:02:54.657056
# 14  2024-02-12T13:48:23.967222
# 15  2024-02-12T13:09:19.665986
# 16  2024-02-12T13:51:22.366380
# 17            2020-07-29T05:00
# 18  2024-02-13T14:25:16.532771
# 19  2024-02-12T14:25:01.735880
# 20  2024-02-13T14:24:12.213582
# 21  2024-07-15T18:00:33.653673
# 22  2024-02-13T01:54:12.946985
# 23  2024-02-13T14:19:57.954551
# 24  2024-02-13T14:26:19.978418
# 25  2023-02-25T14:52:09.326729
# 26  2024-02-12T15:05:34.211400
# 27  2024-06-12T07:41:45.347457
# 28  2024-02-13T14:20:59.825440
# 29  2024-05-15T10:23:32.854925
# 30  2024-06-12T07:38:19.345758
# 31  2023-06-28T10:58:20.137929
# 32  2023-12-26T22:34:04.263530
# 33  2024-02-13T02:52:29.582599
# 34  2024-02-13T14:23:06.735299
# 35  2023-06-26T10:38:00.323984
# 36  2024-02-13T14:22:08.222297
# 37  2024-02-12T17:41:31.729787
# 38  2024-07-15T15:15:28.367546
# 39  2024-07-12T16:27:54.561817
# 40  2024-06-12T07:42:36.910303
# 41  2024-06-12T07:32:43.196678
# 42  2024-03-12T08:49:46.449084
# 43  2024-05-16T14:06:52.149840
# 44  2023-09-20T17:22:28.925900
# 45  2022-07-23T12:18:49.547396
# 46  2024-03-10T11:24:05.201066
# 47  2022-12-01T14:10:17.791769
# 48  2023-04-19T10:48:44.079830
# 49  2023-11-29T10:55:10.039117
# 50  2023-04-19T10:46:29.203565
# 51  2023-04-19T10:42:35.284291
# 52  2023-03-26T23:19:39.125951
# 53  2022-07-03T12:34:31.749038
# 54  2023-11-29T10:56:10.031508
# 55  2023-07-06T12:50:48.807820
# 56  2023-06-28T11:19:54.593488
# 57  2023-12-05T14:19:40.272816
# 58  2024-06-11T00:50:53.277411
# 59  2024-06-03T16:46:00.665854
# 60  2024-01-07T06:23:44.277971
# 61  2024-07-14T18:53:28.735163
# 62  2024-02-12T14:20:24.769832
# 63  2023-07-24T13:01:22.094587
# 64  2024-06-12T07:43:56.243851
# 65  2024-03-08T14:49:13.195793
# 66  2024-06-25T23:56:11.910924
# 67  2023-06-18T01:55:53.343752
# 68  2024-07-15T15:48:50.315500
# 69  2024-04-16T12:44:40.558402
# 70  2024-02-12T14:45:05.702250
# 71  2024-02-13T13:27:17.178263
# 72  2024-07-14T16:59:48.469596
# 73  2024-02-13T09:41:26.379767

# %%
#call the statsbombpy API to get a list of matches for a given competition

#2015/16 La Liga Competition_id = 11, season_id = 27
#2015/16 Bundesliga Competition_id = 9, season_id = 27
#2015/16 Premier League Competition_id = 2, season_id = 27
#2015/16 Serie A Competition_id = 12, season_id = 27
#2015/16 Ligue 1 Competition_id = 7, season_id = 27

#FIFA World Cup 22 competition_id=43, season_id=106
#FIFA World Cup 18 competition_id=43, season_id=3
#Euro 2024 competition_id=55, season_id=282
#Euro 2020 competition_id=55, season_id=43

#Messinin Barça kariyeri verisi



euro_2024_matches = sb.matches(competition_id=55, season_id=282)

#print the first 5 matches listed
euro_2024_matches["match_id"].unique()
# Out:
# array([3942819, 3943043, 3942752, 3942382, 3942349, 3930180, 3930171,
#        3942227, 3942226, 3938645, 3930184, 3941022, 3941021, 3941020,
#        3941019, 3941018, 3941017, 3930182, 3930179, 3940983, 3940878,
#        3930177, 3930173, 3930172, 3930167, 3930168, 3930165, 3930164,
#        3930161, 3938637, 3938640, 3938642, 3938639, 3938641, 3938644,
#        3938643, 3938638, 3930183, 3930181, 3930178, 3930176, 3930175,
#        3930174, 3930170, 3930169, 3930166, 3930163, 3930162, 3930160,
#        3930159, 3930158])

# %%
# Define the list of competition and season pairs
competitions_and_seasons = [
(11, 27, "2015/16 La Liga"),
(9, 27, "2015/16 Bundesliga"),
(2, 27, "2015/16 Premier League"),
(12, 27, "2015/16 Serie A"),
(7, 27, "2015/16 Ligue 1"),
(43, 106, "FIFA World Cup 22"),
(43, 3, "FIFA World Cup 18"),
(55, 282, "Euro 2024"),
(55, 43, "Euro 2020")  
]


# Initialize a dictionary to store the results
match_counts = {}
# Iterate over each competition and season pair
for competition_id, season_id, competition_name in competitions_and_seasons:
    # Retrieve the matches for the given competition and season
    matches = sb.matches(competition_id=competition_id, season_id=season_id)
    
    # Extract unique match IDs
    unique_match_ids = matches["match_id"].unique()
    
    # Store the count of unique match IDs for this competition and season
    match_counts[f'Competition {competition_name}'] = len(unique_match_ids)

# Output the results
for competition_season, count in match_counts.items():
    print(f"{competition_season}: {count} unique matches")
# Out:
# Competition 2015/16 La Liga: 380 unique matches
# Competition 2015/16 Bundesliga: 306 unique matches
# Competition 2015/16 Premier League: 380 unique matches
# Competition 2015/16 Serie A: 380 unique matches
# Competition 2015/16 Ligue 1: 377 unique matches
# Competition FIFA World Cup 22: 64 unique matches
# Competition FIFA World Cup 18: 64 unique matches
# Competition Euro 2024: 51 unique matches
# Competition Euro 2020: 51 unique matches

# %%
# Define the list of competition and season pairs

competitions_and_seasons = [
(11, 90, "La Liga 20/21"),
(11, 42, "La Liga 19/20"),
(11, 4, "La Liga 18/19"),
(11, 1, "La Liga 17/18"),
(11, 2, "La Liga 16/17"),
(11, 27, "La Liga 15/16"),
(11, 26, "La Liga 14/15"),
(11, 25, "La Liga 13/14"),
(11, 24, "La Liga 12/13"),
(11, 23, "La Liga 11/12"),
(11, 22, "La Liga 10/11"),
(11, 21, "La Liga 09/10"),
(11, 41, "La Liga 08/09"),
(11, 40, "La Liga 07/08"),
(11, 39, "La Liga 06/07"),
(11, 38, "La Liga 05/06"),
(11, 37, "La Liga 04/05")]


# Initialize a dictionary to store the results
match_counts = {}
# Iterate over each competition and season pair
for competition_id, season_id, competition_name in competitions_and_seasons:
    # Retrieve the matches for the given competition and season
    matches = sb.matches(competition_id=competition_id, season_id=season_id)
    
    # Extract unique match IDs
    unique_match_ids = matches["match_id"].unique()
    
    # Store the count of unique match IDs for this competition and season
    match_counts[f'Competition {competition_name}'] = len(unique_match_ids)

# Output the results
for competition_season, count in match_counts.items():
    print(f"{competition_season}: {count} unique matches")
# Out:
# Competition La Liga 20/21: 35 unique matches
# Competition La Liga 19/20: 33 unique matches
# Competition La Liga 18/19: 34 unique matches
# Competition La Liga 17/18: 36 unique matches
# Competition La Liga 16/17: 34 unique matches
# Competition La Liga 15/16: 380 unique matches
# Competition La Liga 14/15: 38 unique matches
# Competition La Liga 13/14: 31 unique matches
# Competition La Liga 12/13: 32 unique matches
# Competition La Liga 11/12: 37 unique matches
# Competition La Liga 10/11: 33 unique matches
# Competition La Liga 09/10: 35 unique matches
# Competition La Liga 08/09: 31 unique matches
# Competition La Liga 07/08: 28 unique matches
# Competition La Liga 06/07: 26 unique matches
# Competition La Liga 05/06: 17 unique matches
# Competition La Liga 04/05: 7 unique matches

# %%
#create a variable for the team you want to look into
team="England"

#filter for only matches that the focus team played in
matches_df = euro_2024_matches[(euro_2024_matches['home_team'] == team)|(euro_2024_matches['away_team'] == team)]

#sort by match date to get the most recent match
matches_df=matches_df.sort_values(by='match_date', ascending=False)

# %%
matches_df.head(5)
# Out:
#     match_id  match_date      kick_off         competition season  \
# 1    3943043  2024-07-14  22:00:00.000  Europe - UEFA Euro   2024
# 0    3942819  2024-07-10  22:00:00.000  Europe - UEFA Euro   2024
# 7    3942227  2024-07-06  19:00:00.000  Europe - UEFA Euro   2024
# 16   3941017  2024-06-30  19:00:00.000  Europe - UEFA Euro   2024
# 38   3930181  2024-06-25  22:00:00.000  Europe - UEFA Euro   2024
#
#       home_team    away_team  home_score  away_score match_status  \
# 1         Spain      England           2           1    available
# 0   Netherlands      England           1           2    available
# 7       England  Switzerland           1           1    available
# 16      England     Slovakia           2           1    available
# 38      England     Slovenia           0           0    available
#
#    match_status_360                last_updated            last_updated_360  \
# 1         available  2024-07-15T15:48:50.315500  2024-07-15T15:52:24.778809
# 0         available  2024-07-15T07:54:23.583297  2024-07-15T07:57:36.684453
# 7         available  2024-07-14T15:55:52.682165  2024-07-14T15:57:51.414762
# 16        available  2024-07-10T11:29:00.136519  2024-07-10T11:31:44.852038
# 38        available  2024-07-10T14:26:49.966712  2024-07-10T14:27:59.561474
#
#     match_week competition_stage                stadium            referee  \
# 1            7             Final  Olympiastadion Berlin  François Letexier
# 0            6       Semi-finals      Signal-Iduna-Park       Felix Zwayer
# 7            5    Quarter-finals     Merkur Spiel-Arena     Daniele Orsato
# 16           4       Round of 16          VELTINS-Arena   Halil Umut Meler
# 38           3       Group Stage    RheinEnergieStadion     Clément Turpin
#
#                  home_managers      away_managers data_version  \
# 1   Luis de la Fuente Castillo   Gareth Southgate        1.1.0
# 0                Ronald Koeman   Gareth Southgate        1.1.0
# 7             Gareth Southgate        Murat Yakin        1.1.0
# 16            Gareth Southgate  Francesco Calzona        1.1.0
# 38            Gareth Southgate         Matjaž Kek        1.1.0
#
#    shot_fidelity_version xy_fidelity_version
# 1                      2                   2
# 0                      2                   2
# 7                      2                   2
# 16                     2                   2
# 38                     2                   2

# %%
#create a variable containing the first match id in the data frame
latest_match_id = matches_df.match_id.iloc[0]

#latest_match_id=3943043

# %%
#call the statsbombpy events API to bring in the event data for the match
events_df = sb.events(match_id=latest_match_id)

#print the first 5 rows of data
events_df.head(5)
# Out:
#   50_50 ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0   NaN                  NaN                            NaN              NaN
# 1   NaN                  NaN                            NaN              NaN
# 2   NaN                  NaN                            NaN              NaN
# 3   NaN                  NaN                            NaN              NaN
# 4   NaN                  NaN                            NaN              NaN
#
#   block_offensive block_save_block carry_end_location clearance_aerial_won  \
# 0             NaN              NaN                NaN                  NaN
# 1             NaN              NaN                NaN                  NaN
# 2             NaN              NaN                NaN                  NaN
# 3             NaN              NaN                NaN                  NaN
# 4             NaN              NaN                NaN                  NaN
#
#   clearance_body_part clearance_head clearance_left_foot clearance_right_foot  \
# 0                 NaN            NaN                 NaN                  NaN
# 1                 NaN            NaN                 NaN                  NaN
# 2                 NaN            NaN                 NaN                  NaN
# 3                 NaN            NaN                 NaN                  NaN
# 4                 NaN            NaN                 NaN                  NaN
#
#   counterpress dribble_nutmeg dribble_outcome dribble_overrun duel_outcome  \
# 0          NaN            NaN             NaN             NaN          NaN
# 1          NaN            NaN             NaN             NaN          NaN
# 2          NaN            NaN             NaN             NaN          NaN
# 3          NaN            NaN             NaN             NaN          NaN
# 4          NaN            NaN             NaN             NaN          NaN
#
#   duel_type  duration foul_committed_advantage foul_committed_card  \
# 0       NaN       0.0                      NaN                 NaN
# 1       NaN       0.0                      NaN                 NaN
# 2       NaN       0.0                      NaN                 NaN
# 3       NaN       0.0                      NaN                 NaN
# 4       NaN       0.0                      NaN                 NaN
#
#   foul_committed_offensive foul_won_advantage foul_won_defensive  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4                      NaN                NaN                NaN
#
#   goalkeeper_body_part goalkeeper_end_location goalkeeper_outcome  \
# 0                  NaN                     NaN                NaN
# 1                  NaN                     NaN                NaN
# 2                  NaN                     NaN                NaN
# 3                  NaN                     NaN                NaN
# 4                  NaN                     NaN                NaN
#
#   goalkeeper_position goalkeeper_technique goalkeeper_type  \
# 0                 NaN                  NaN             NaN
# 1                 NaN                  NaN             NaN
# 2                 NaN                  NaN             NaN
# 3                 NaN                  NaN             NaN
# 4                 NaN                  NaN             NaN
#
#                                      id  index injury_stoppage_in_chain  \
# 0  50aa204f-5d65-4145-8597-5d5628fb7898      1                      NaN
# 1  a279cbee-9ab3-4cfb-9c51-27cacc1bf2a2      2                      NaN
# 2  d2126e70-9f04-4bb7-ba2b-9377836d1757      3                      NaN
# 3  54d78bfa-4146-42bd-acdc-97bcd393dd81      4                      NaN
# 4  7230470a-8ceb-4eb8-a66f-d72a2afb12d6   1706                      NaN
#
#   interception_outcome location  match_id  minute off_camera  out  \
# 0                  NaN      NaN   3943043       0        NaN  NaN
# 1                  NaN      NaN   3943043       0        NaN  NaN
# 2                  NaN      NaN   3943043       0        NaN  NaN
# 3                  NaN      NaN   3943043       0        NaN  NaN
# 4                  NaN      NaN   3943043      45        NaN  NaN
#
#   pass_aerial_won  pass_angle pass_assisted_shot_id pass_body_part pass_cross  \
# 0             NaN         NaN                   NaN            NaN        NaN
# 1             NaN         NaN                   NaN            NaN        NaN
# 2             NaN         NaN                   NaN            NaN        NaN
# 3             NaN         NaN                   NaN            NaN        NaN
# 4             NaN         NaN                   NaN            NaN        NaN
#
#   pass_cut_back pass_end_location pass_goal_assist pass_height  \
# 0           NaN               NaN              NaN         NaN
# 1           NaN               NaN              NaN         NaN
# 2           NaN               NaN              NaN         NaN
# 3           NaN               NaN              NaN         NaN
# 4           NaN               NaN              NaN         NaN
#
#   pass_inswinging  pass_length pass_no_touch pass_outcome pass_outswinging  \
# 0             NaN          NaN           NaN          NaN              NaN
# 1             NaN          NaN           NaN          NaN              NaN
# 2             NaN          NaN           NaN          NaN              NaN
# 3             NaN          NaN           NaN          NaN              NaN
# 4             NaN          NaN           NaN          NaN              NaN
#
#   pass_recipient  pass_recipient_id pass_shot_assist pass_switch  \
# 0            NaN                NaN              NaN         NaN
# 1            NaN                NaN              NaN         NaN
# 2            NaN                NaN              NaN         NaN
# 3            NaN                NaN              NaN         NaN
# 4            NaN                NaN              NaN         NaN
#
#   pass_technique pass_through_ball pass_type  period  play_pattern player  \
# 0            NaN               NaN       NaN       1  Regular Play    NaN
# 1            NaN               NaN       NaN       1  Regular Play    NaN
# 2            NaN               NaN       NaN       1  Regular Play    NaN
# 3            NaN               NaN       NaN       1  Regular Play    NaN
# 4            NaN               NaN       NaN       2  Regular Play    NaN
#
#    player_id position  possession possession_team  possession_team_id  \
# 0        NaN      NaN           1           Spain                 772
# 1        NaN      NaN           1           Spain                 772
# 2        NaN      NaN           1           Spain                 772
# 3        NaN      NaN           1           Spain                 772
# 4        NaN      NaN          79           Spain                 772
#
#                            related_events  second shot_aerial_won  \
# 0                                     NaN       0             NaN
# 1                                     NaN       0             NaN
# 2  [54d78bfa-4146-42bd-acdc-97bcd393dd81]       0             NaN
# 3  [d2126e70-9f04-4bb7-ba2b-9377836d1757]       0             NaN
# 4  [cb9ba06c-a673-448d-ab21-755d330fcadc]       0             NaN
#
#   shot_body_part shot_deflected shot_end_location shot_first_time  \
# 0            NaN            NaN               NaN             NaN
# 1            NaN            NaN               NaN             NaN
# 2            NaN            NaN               NaN             NaN
# 3            NaN            NaN               NaN             NaN
# 4            NaN            NaN               NaN             NaN
#
#   shot_freeze_frame shot_key_pass_id shot_one_on_one shot_outcome  \
# 0               NaN              NaN             NaN          NaN
# 1               NaN              NaN             NaN          NaN
# 2               NaN              NaN             NaN          NaN
# 3               NaN              NaN             NaN          NaN
# 4               NaN              NaN             NaN          NaN
#
#    shot_statsbomb_xg shot_technique shot_type substitution_outcome  \
# 0                NaN            NaN       NaN                  NaN
# 1                NaN            NaN       NaN                  NaN
# 2                NaN            NaN       NaN                  NaN
# 3                NaN            NaN       NaN                  NaN
# 4                NaN            NaN       NaN                  NaN
#
#    substitution_outcome_id substitution_replacement  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#    substitution_replacement_id  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                              tactics     team  team_id  \
# 0  {'formation': 4231, 'lineup': [{'player': {'id...    Spain      772
# 1  {'formation': 4231, 'lineup': [{'player': {'id...  England      768
# 2                                                NaN  England      768
# 3                                                NaN    Spain      772
# 4                                                NaN  England      768
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000   Half Start            NaN
# 3  00:00:00.000   Half Start            NaN
# 4  00:00:00.000   Half Start            NaN

# %%
#print a list of columns available in the event data
events_df.columns
# Out:
# Index(['50_50', 'ball_receipt_outcome', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'block_save_block',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive', 'foul_won_advantage',
#        'foul_won_defensive', 'goalkeeper_body_part', 'goalkeeper_end_location',
#        'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_technique',
#        'goalkeeper_type', 'id', 'index', 'injury_stoppage_in_chain',
#        'interception_outcome', 'location', 'match_id', 'minute', 'off_camera',
#        'out', 'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
#        'pass_body_part', 'pass_cross', 'pass_cut_back', 'pass_end_location',
#        'pass_goal_assist', 'pass_height', 'pass_inswinging', 'pass_length',
#        'pass_no_touch', 'pass_outcome', 'pass_outswinging', 'pass_recipient',
#        'pass_recipient_id', 'pass_shot_assist', 'pass_switch',
#        'pass_technique', 'pass_through_ball', 'pass_type', 'period',
#        'play_pattern', 'player', 'player_id', 'position', 'possession',
#        'possession_team', 'possession_team_id', 'related_events', 'second',
#        'shot_aerial_won', 'shot_body_part', 'shot_deflected',
#        'shot_end_location', 'shot_first_time', 'shot_freeze_frame',
#        'shot_key_pass_id', 'shot_one_on_one', 'shot_outcome',
#        'shot_statsbomb_xg', 'shot_technique', 'shot_type',
#        'substitution_outcome', 'substitution_outcome_id',
#        'substitution_replacement', 'substitution_replacement_id', 'tactics',
#        'team', 'team_id', 'timestamp', 'type', 'under_pressure'],
#       dtype='object')

# %%
#separate start and end locations from coordinates
events_df[['x', 'y']] = events_df['location'].apply(pd.Series)
events_df[['pass_end_x', 'pass_end_y']] = events_df['pass_end_location'].apply(pd.Series)
events_df[['carry_end_x', 'carry_end_y']] = events_df['carry_end_location'].apply(pd.Series)

# %% [markdown]
# # Example One: Passes and Carries into the Final Third
#
# "Which players progressed the ball into the final third the most?"

# %% [markdown]
# ![Screenshot 2024-07-08 at 18.01.42.png](data:image/png;base64,...)

# %% [markdown]
# ## Data Manipulation

# %%
events_df.pass_outcome.unique()
# Out:
# array([nan, 'Out', 'Incomplete', 'Unknown', 'Pass Offside'], dtype=object)

# %%
#filter for events done by the focus team
#filter by event type to get only passes
#filter for passes that started outside of the final third
#filter for passes that ended in the final third
#filter for completed passes
f3rd_passes=events_df[(events_df.team==team)&(events_df.type=="Pass")&(events_df.x<80)&(events_df.pass_end_x>80)&(events_df.pass_outcome.isna())]

#get count for each player
f3rd_passes_count=f3rd_passes.groupby('player').size().reset_index()

# %%
f3rd_passes_count
# Out:
#             player  0
# 0      Cole Palmer  1
# 1       Harry Kane  1
# 2      John Stones  2
# 3  Jordan Pickford  1
# 4  Jude Bellingham  1
# 5      Kyle Walker  4
# 6       Marc Guehi  1

# %%
#rename second column
f3rd_passes_count.rename(columns={f3rd_passes_count.columns[1]: "Passes" }, inplace = True)

# %%
f3rd_passes_count
# Out:
#             player  Passes
# 0      Cole Palmer       1
# 1       Harry Kane       1
# 2      John Stones       2
# 3  Jordan Pickford       1
# 4  Jude Bellingham       1
# 5      Kyle Walker       4
# 6       Marc Guehi       1

# %%
#get final third carries for focus team
f3rd_carries=events_df[(events_df.type=="Carry")&(events_df.x<80)&(events_df.carry_end_x>80)&(events_df.team==team)]

#get count for each player
f3rd_carries_count=f3rd_carries.groupby('player').size().reset_index()

#rename second column
f3rd_carries_count.rename(columns={f3rd_carries_count.columns[1]: "Carries" }, inplace = True)

# %%
f3rd_carries_count
# Out:
#             player  Carries
# 0      Bukayo Saka        4
# 1      Cole Palmer        1
# 2       Harry Kane        1
# 3      John Stones        1
# 4  Jude Bellingham        4
# 5        Luke Shaw        1
# 6       Phil Foden        1

# %%
#combine dataframes
progressions_df=pd.merge(f3rd_passes_count, f3rd_carries_count,
                    how="outer", on=["player"])

# %%
progressions_df
# Out:
#             player  Passes  Carries
# 0      Bukayo Saka     NaN      4.0
# 1      Cole Palmer     1.0      1.0
# 2       Harry Kane     1.0      1.0
# 3      John Stones     2.0      1.0
# 4  Jordan Pickford     1.0      NaN
# 5  Jude Bellingham     1.0      4.0
# 6      Kyle Walker     4.0      NaN
# 7        Luke Shaw     NaN      1.0
# 8       Marc Guehi     1.0      NaN
# 9       Phil Foden     NaN      1.0

# %%
#add 0 where value is NaN
progressions_df=progressions_df.fillna(0)

# %%
progressions_df
# Out:
#             player  Passes  Carries
# 0      Bukayo Saka     0.0      4.0
# 1      Cole Palmer     1.0      1.0
# 2       Harry Kane     1.0      1.0
# 3      John Stones     2.0      1.0
# 4  Jordan Pickford     1.0      0.0
# 5  Jude Bellingham     1.0      4.0
# 6      Kyle Walker     4.0      0.0
# 7        Luke Shaw     0.0      1.0
# 8       Marc Guehi     1.0      0.0
# 9       Phil Foden     0.0      1.0

# %%
#add a new column with the total
progressions_df['total']=progressions_df['Passes']+progressions_df['Carries']

# %%
progressions_df
# Out:
#             player  Passes  Carries  total
# 0      Bukayo Saka     0.0      4.0    4.0
# 1      Cole Palmer     1.0      1.0    2.0
# 2       Harry Kane     1.0      1.0    2.0
# 3      John Stones     2.0      1.0    3.0
# 4  Jordan Pickford     1.0      0.0    1.0
# 5  Jude Bellingham     1.0      4.0    5.0
# 6      Kyle Walker     4.0      0.0    4.0
# 7        Luke Shaw     0.0      1.0    1.0
# 8       Marc Guehi     1.0      0.0    1.0
# 9       Phil Foden     0.0      1.0    1.0

# %%
progressions_df.sort_values(by='total', ascending=False, inplace=True)

# %%
progressions_df
# Out:
#             player  Passes  Carries  total
# 5  Jude Bellingham     1.0      4.0    5.0
# 0      Bukayo Saka     0.0      4.0    4.0
# 6      Kyle Walker     4.0      0.0    4.0
# 3      John Stones     2.0      1.0    3.0
# 1      Cole Palmer     1.0      1.0    2.0
# 2       Harry Kane     1.0      1.0    2.0
# 4  Jordan Pickford     1.0      0.0    1.0
# 7        Luke Shaw     0.0      1.0    1.0
# 8       Marc Guehi     1.0      0.0    1.0
# 9       Phil Foden     0.0      1.0    1.0

# %% [markdown]
# ## Visualise

# %%
#create stacked bar chart
pass_colour='#e21017'
carry_colour='blue'

#sort to get lowest values first (so that it plots in the correct order on our bar chart)
progressions_df.sort_values(by='total', ascending=True, inplace=True)

#include only relevant columns
barchart_df=progressions_df[["player", "Passes", "Carries"]]


#create figure and set some style parameters
plt.figure(figsize = (15,15))
sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})
sns.set_style("ticks")

#create bar chart
barchart_df.set_index('player').plot(kind='barh', stacked=True,color=[pass_colour, carry_colour],legend=True,figsize=(10,10))

#add chart labels and title
plt.xlabel(xlabel="Progressions into Final 3rd",fontdict = { 'fontsize': 12, 'weight':'semibold'})
plt.ylabel(ylabel="Player",fontdict = { 'fontsize': 12, 'weight':'semibold'})
plt.title(f"{team}: Progressions into Final 3rd",fontdict = { 'fontsize': 24, 'weight':'bold'})

#keep two axes
sns.despine(top=True, right=True, left=False, bottom=False)
plt.autoscale()
plt.show()

# %%
#visualise for a given player
player_name="Jude Bellingham"

player_passes=f3rd_passes[(f3rd_passes.player==player_name)]
player_carries=f3rd_carries[(f3rd_carries.player==player_name)]

#set up the pitch
pitch = Pitch(pitch_type='statsbomb', pitch_color='white', line_zorder=2, line_color='black')
fig, ax = pitch.draw(figsize=(16, 11),constrained_layout=True, tight_layout=False)
fig.set_facecolor('white')

#plot the passes
pitch.arrows(player_passes.x, player_passes.y,
player_passes.pass_end_x, player_passes.pass_end_y, width=3,
headwidth=8, headlength=5, color=pass_colour, ax=ax, zorder=2, label = "Pass")

#plot the carries
pitch.arrows(player_carries.x, player_carries.y,
player_carries.carry_end_x, player_carries.carry_end_y, width=3,
headwidth=8, headlength=5, color=carry_colour, ax=ax, zorder=2, label = "Carry")

#plot the legend
ax.legend(facecolor='white', handlelength=5, edgecolor='None', fontsize=20, loc='best')

#set title of viz
ax_title = ax.set_title(f'{player_name} Progressions into Final 3rd: Euros Final', fontsize=30,color='black')

# %% [markdown]
# # Example Two: Comparing Touch Maps
#
# "Was player A's on ball position similar to player B's?"

# %% [markdown]
# ## Data Manipulation

# %%
player1="Luke Shaw"
player2="Kyle Walker"
touches=['Pass', 'Ball Receipt*', 'Carry', 'Clearance', 'Foul Won', 'Block',
'Ball Recovery', 'Duel', 'Dribble', 'Interception', 'Miscontrol', 'Shot']

# %%
player1_df=events_df[(events_df.player==player1)&(events_df.type.isin(touches))]
player2_df=events_df[(events_df.player==player2)&(events_df.type.isin(touches))]

# %% [markdown]
# ## Visualise

# %%
#create colour map
colour1="white"
colour2="#c3c3c3"
colour3="#e21017"
cmaplist = [colour1, colour2, colour3]
cmap = LinearSegmentedColormap.from_list("", cmaplist)

# %%
path_eff = [path_effects.Stroke(linewidth=3, foreground='black'),
            path_effects.Normal()]

#create a grid of pitches
#define pitch style
pitch = VerticalPitch(pitch_type='statsbomb', line_zorder=2, line_color='#000000', linewidth=2,half=False)

#create a grid - in this example, one row of two pitches
fig, axs = pitch.grid(nrows=1, ncols=2
                      ,figheight=16,
                      grid_width=0.65,
                      endnote_height=0.03, endnote_space=0.05,
                      axis=False,title_space=0.02, title_height=0.06, grid_height=0.8)

#get data for heatmap
#player1
bin_statistic1 = pitch.bin_statistic(player1_df.x, player1_df.y, statistic='count',
bins=(6, 4),normalize=True)
#player2
bin_statistic2 = pitch.bin_statistic(player2_df.x, player2_df.y, statistic='count',
bins=(6, 4),normalize=True)

#calculate vmax value
#we want both our heatmaps to use the same colour spectrum
vmax1=bin_statistic1['statistic'].max()
vmax2=bin_statistic2['statistic'].max()

if vmax1>vmax2:
  vmax=vmax1
else:
  vmax=vmax2

#set vmin as zero
vmin=0

#plot heatmap for player1
heatmap1 = pitch.heatmap(bin_statistic1, ax=axs['pitch'][0], cmap=cmap, vmax=vmax, vmin=vmin)

#add percentages for each zone
annotate1 = pitch.label_heatmap(bin_statistic1, color='white',
                                path_effects=path_eff, fontsize=50, ax=axs['pitch'][0],
                                str_format='{:.0%}',
                                ha='center', va='center',
                                exclude_zeros=True)

#add name of player to the top of the heatmap
ax_text(0, 125, f'{player1}: Touches', ha='left', c='black',va='center', fontsize=45,ax=axs['pitch'][0],style='italic')


#plot heatmap for player2
heatmap2 = pitch.heatmap(bin_statistic2, ax=axs['pitch'][1], cmap=cmap, vmax=vmax, vmin=vmin)

#add percentages for each zone
annotate2 = pitch.label_heatmap(bin_statistic2, color='white',
                                path_effects=path_eff, fontsize=50, ax=axs['pitch'][1],
                                str_format='{:.0%}',
                                ha='center', va='center',
                                exclude_zeros=True)

#add name of player to the top of the heatmap
ax_text(0, 125, f'{player2}: Touches', ha='left', c='black',va='center', fontsize=45,ax=axs['pitch'][1],style='italic')

# %% [markdown]
# # Bonus
#
# Get top xG Performers across the tournament. Create a shot map for the top player.

# %%
# get event data for entire season
comp_events_df=sb.competition_events(
     country='Europe',
     division='UEFA Euro',
     season='2024',
     gender="male")
# Out:
# /Users/emirysaglam/GitHub/Bitirme/bitirme-venv/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/emirysaglam/GitHub/Bitirme/bitirme-venv/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/emirysaglam/GitHub/Bitirme/bitirme-venv/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/emirysaglam/GitHub/Bitirme/bitirme-venv/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/emirysaglam/GitHub/Bitirme/bitirme-venv/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/emirysaglam/GitHub/Bitirme/bitirme-venv/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
comp_events_df[['x', 'y']] = comp_events_df['location'].apply(pd.Series)
comp_events_df[['pass_end_x', 'pass_end_y']] = comp_events_df['pass_end_location'].apply(pd.Series)
comp_events_df[['carry_end_x', 'carry_end_y']] = comp_events_df['carry_end_location'].apply(pd.Series)
# Out:
# /var/folders/6j/1nsywzcs1v5_6gn_3972hssr0000gn/T/ipykernel_6018/2447140862.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   comp_events_df[['x', 'y']] = comp_events_df['location'].apply(pd.Series)
# /var/folders/6j/1nsywzcs1v5_6gn_3972hssr0000gn/T/ipykernel_6018/2447140862.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   comp_events_df[['x', 'y']] = comp_events_df['location'].apply(pd.Series)
# /var/folders/6j/1nsywzcs1v5_6gn_3972hssr0000gn/T/ipykernel_6018/2447140862.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   comp_events_df[['pass_end_x', 'pass_end_y']] = comp_events_df['pass_end_location'].apply(pd.Series)
# /var/folders/6j/1nsywzcs1v5_6gn_3972hssr0000gn/T/ipykernel_6018/2447140862.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   comp_events_df[['pass_end_x', 'pass_end_y']] = comp_events_df['pass_end_location'].apply(pd.Series)
# /var/folders/6j/1nsywzcs1v5_6gn_3972hssr0000gn/T/ipykernel_6018/2447140862.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   comp_events_df[['carry_end_x', 'carry_end_y']] = comp_events_df['carry_end_location'].apply(pd.Series)
# /var/folders/6j/1nsywzcs1v5_6gn_3972hssr0000gn/T/ipykernel_6018/2447140862.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   comp_events_df[['carry_end_x', 'carry_end_y']] = comp_events_df['carry_end_location'].apply(pd.Series)

# %%
# get non penalty shots and non penalty goals
shots_df=comp_events_df[(comp_events_df.type=="Shot")&(comp_events_df.shot_type!="Penalty")]
goals_df=comp_events_df[(comp_events_df.type=="Shot")&(comp_events_df.shot_type!="Penalty")&(comp_events_df.shot_outcome=="Goal")]

#shots
#get count for each player, include team info
shots_count=shots_df.groupby(['player','team']).size().reset_index()

#rename second column
shots_count.rename(columns={shots_count.columns[2]: "np Shots" }, inplace = True)


#goals
#get count for each player, include team info
goals_count=goals_df.groupby(['player', 'team']).size().reset_index()

#rename second column
goals_count.rename(columns={goals_count.columns[2]: "np Goals" }, inplace = True)


#xG
#get count for each player, include team info
xg_sum=shots_df.groupby(['player', 'team'])['shot_statsbomb_xg'].sum().reset_index()

#rename second column
xg_sum.rename(columns={xg_sum.columns[2]: "np xG" }, inplace = True)

#round up to 2 decimal places
xg_sum['np xG']=xg_sum['np xG'].round(2)

# %%
#combine dataframes
shot_stats=pd.merge(shots_count, goals_count,
                    how="outer", on=["player", "team"])

shot_stats=pd.merge(shot_stats, xg_sum,
                    how="outer", on=["player", "team"])

# %%
#add 0 where value is NaN
shot_stats=shot_stats.fillna(0)

#sort to get top goalscorers, change by=' ' to get top xG, or top Shots
shot_stats=shot_stats.sort_values(by='np xG', ascending=False)

# %%
shot_stats.head(10)
# Out:
#                                   player         team  np Shots  np Goals  \
# 109                           Harry Kane      England        17       2.0
# 154                          Kai Havertz      Germany        17       0.0
# 56   Cristiano Ronaldo dos Santos Aveiro     Portugal        22       0.0
# 206                        Memphis Depay  Netherlands        18       1.0
# 276                 Romelu Lukaku Menama      Belgium        11       0.0
# 171                 Kylian Mbappé Lottin       France        23       0.0
# 173          Lamine Yamal Nasraoui Ebana        Spain        18       1.0
# 42                   Breel-Donald Embolo  Switzerland         8       2.0
# 329           Álvaro Borja Morata Martín        Spain        14       1.0
# 53                 Christoph Baumgartner      Austria         8       1.0
#
#      np xG
# 109   2.27
# 154   2.21
# 56    2.19
# 206   1.95
# 276   1.75
# 171   1.72
# 173   1.59
# 42    1.57
# 329   1.57
# 53    1.55

# %%
#Shot map for top scorer
xg_player=shot_stats.player.iloc[0]

player_goals_df=goals_df[(goals_df.player==xg_player)]

player_shots_df=shots_df[(shots_df.player==xg_player)&(shots_df.shot_outcome!="Goal")]

# %%
pitch = VerticalPitch(pitch_type='statsbomb',half=True,pad_bottom=-11)
fig, ax = pitch.draw(figsize=(12, 10))

shot_colour='red'
goal_colour='blue'

shots = pitch.scatter(player_shots_df.x, player_shots_df.y,
#make size relative to xG value
s=player_shots_df.shot_statsbomb_xg*1000,
c=shot_colour,
label='Shots',
marker='o',
alpha=0.5,
ax=ax)

goals = pitch.scatter(player_goals_df.x, player_goals_df.y,
#make size relative to xG value
s=player_goals_df.shot_statsbomb_xg*1000,
c='white',
edgecolors=goal_colour,
label='Goals',
marker='football',
ax=ax)

#plot the legend
ax.legend(facecolor='white', handlelength=5, edgecolor='None', fontsize=20, loc='best')

ax_text(0, 125, f'{xg_player}: Shot Map, Euro 2024', ha='left', c='black',va='center', fontsize=25,ax=ax,style='italic')
